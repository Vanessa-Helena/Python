# %% [markdown]
# <a href="https://colab.research.google.com/github/Vanessa-Helena/Python/blob/master/atividade_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importação das bibliotecas
import cv2
from matplotlib import pyplot as plt
#import matplotlib.pyplot as plt
import numpy as np

# !wget "https://olharconceito.com.br/imgsite/noticias/vanessa.png" -O dt.jpg
imgNome = './dt.jpg'
# Out:
# --2021-03-25 00:15:03--  https://olharconceito.com.br/imgsite/noticias/vanessa.png
# Resolving olharconceito.com.br (olharconceito.com.br)... 34.95.69.47
# Connecting to olharconceito.com.br (olharconceito.com.br)|34.95.69.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 295988 (289K) [image/png]
# Saving to: ‘dt.jpg’
#
# dt.jpg              100%[===================>] 289.05K  --.-KB/s    in 0.004s
#
# 2021-03-25 00:15:03 (71.5 MB/s) - ‘dt.jpg’ saved [295988/295988]

# %%
  img = cv2.imread(imgNome)
  plt.imshow(img)
  print("\nImagem BGR")
  plt.show()
# Out:
# Imagem BGR

# %%
dimensions = img.shape
dimensions
# Out:
# (642, 620, 3)

# %%
imgrgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(imgrgb)
print("\nImagem RGB")
plt.show()
# Out:
# Imagem RGB

# %%
imgNC = cv2.cvtColor(imgrgb, cv2.COLOR_RGB2GRAY)

# %%
plt.imshow(imgNC,'gray')

# %%
imgNC = cv2.cvtColor(imgrgb, cv2.COLOR_RGB2HSV)

# %%
plt.imshow(imgNC)

# %%
imgrgb[1:280,1:280,:]
# Out:
# array([[[153, 139, 130],
#         [156, 139, 131],
#         [163, 148, 141],
#         ...,
#         [124, 119, 113],
#         [125, 120, 116],
#         [132, 127, 123]],
#
#        [[150, 137, 128],
#         [152, 137, 130],
#         [161, 148, 140],
#         ...,
#         [119, 116, 109],
#         [121, 118, 111],
#         [125, 122, 115]],
#
#        [[148, 138, 129],
#         [153, 140, 132],
#         [155, 142, 136],
#         ...,
#         [115, 114, 109],
#         [114, 111, 106],
#         [113, 110, 105]],
#
#        ...,
#
#        [[ 46,  44,  49],
#         [ 52,  50,  53],
#         [ 60,  58,  59],
#         ...,
#         [199, 146, 115],
#         [189, 138, 109],
#         [177, 127, 100]],
#
#        [[ 48,  46,  51],
#         [ 53,  51,  54],
#         [ 60,  58,  59],
#         ...,
#         [194, 141, 110],
#         [186, 135, 106],
#         [178, 128, 101]],
#
#        [[ 48,  46,  51],
#         [ 53,  51,  54],
#         [ 58,  56,  59],
# ...

# %%
plt.imshow(imgrgb[1:300,1:300,:])

# %%
plt.imshow(imgNC[1:300,1:300,:])

# %%
# !wget "https://www.dropbox.com/sh/88d8vp9binlnavf/AACd9wE7EqoExwJrVbtOXi3Oa?dl=0&preview=DJI_0003.JPG" -O DJI_0003.jpg
DJI_0003 = './DJI_0003.jpg'
# Out:
# --2021-03-25 01:56:19--  https://www.dropbox.com/sh/88d8vp9binlnavf/AACd9wE7EqoExwJrVbtOXi3Oa?dl=0&preview=DJI_0003.JPG
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.5.18, 2620:100:601d:18::a27d:512
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.5.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /sh/raw/88d8vp9binlnavf/AACd9wE7EqoExwJrVbtOXi3Oa [following]
# --2021-03-25 01:56:19--  https://www.dropbox.com/sh/raw/88d8vp9binlnavf/AACd9wE7EqoExwJrVbtOXi3Oa
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucc207685bd6d1da13f65715c1ae.dl.dropboxusercontent.com/zip_download_get/AusfVgytI_d3W0mW3OnSm15LUC7EVYZSxubU9V7hp_5BiCowJGT7xPqN2GdtZZcHKnRnsxi6Vtf0StiUnDD0iUMIXkmQHT31jboGhPSRi713cw [following]
# ...
